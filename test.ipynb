# %% [markdown]
# <a href="https://colab.research.google.com/github/yamamoto-taisei-nalgo-intern/test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,2*np.pi,100)
y = np.cos(x)
plt.plot(x,y)
